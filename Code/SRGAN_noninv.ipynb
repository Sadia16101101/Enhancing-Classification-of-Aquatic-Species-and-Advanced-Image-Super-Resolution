# %%
from google.colab import drive
import os
import cv2
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import Model

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load SRGAN model from TensorFlow Hub
srgan_model = hub.load('https://tfhub.dev/captain-pool/esrgan-tf2/1')

# %%
# Setup VGG19 model for perceptual loss
vgg = VGG19(include_top=False, weights='imagenet')
vgg.trainable = False
feature_extractor = Model(inputs=vgg.input, outputs=vgg.get_layer('block5_conv4').output)
feature_extractor.trainable = False

def perceptual_loss(y_true, y_pred):
    # Compute VGG feature-based loss
    return tf.reduce_mean(tf.square(feature_extractor(y_true) - feature_extractor(y_pred)))

def preprocess_image(image):
    resized_image = cv2.resize(image, (224, 224))
    normalized_image = resized_image.astype(np.float32) / 255.0
    return normalized_image

def super_resolve(image):
    preprocessed_image = preprocess_image(image)
    preprocessed_image = np.expand_dims(preprocessed_image, axis=0)
    sr_image = srgan_model(preprocessed_image)
    sr_image = tf.squeeze(sr_image).numpy()
    sr_image = (sr_image.clip(0, 1) * 255.0).astype(np.uint8)
    sr_image = cv2.resize(sr_image, (image.shape[1], image.shape[0]))
    return sr_image
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
# Define paths
source_dir = '/content/drive/MyDrive/aqua_data/non_invasive'
output_dir = '/content/drive/MyDrive/SRCNN/SRGAN/non_inv'

# %%
# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Check if the source directory is accessible and list some files
try:
    files = os.listdir(source_dir)
    print("Number of files:", len(files))
    for file in files[:10]:  # Adjust to list fewer files if the number is very large
        print(file)
except Exception as e:
    print(str(e))

# Process each image
for file in os.listdir(source_dir):
    try:
        print('Processing image:', file)
        output_path = os.path.join(output_dir, file)
        # Load image
        image_path = os.path.join(source_dir, file)
        degraded = cv2.imread(image_path)
        if degraded is None:
            continue

        # Super-resolve the image
        sr_image = super_resolve(degraded)

        # Save the super-resolved image
        cv2.imwrite(output_path, sr_image)
        print('Saved super-resolved image to', output_path)

    except Exception as e:
        print('Error processing image {}: {}'.format(file, str(e)))
# Out:
# [Errno 5] Input/output error: '/content/drive/MyDrive/aqua_data/non_invasive'
# Processing image: Imageio560_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_025.png
# Processing image: Imageio562_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_023.png
# Processing image: Imagei072_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_014.png
# Processing image: Imagei528_070.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_070.png
# Processing image: Imagei078_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_007.png
# Processing image: Imagei073_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_014.png
# Processing image: Imagei081_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_001.png
# Processing image: Imagei077_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_007.png
# Processing image: Imageio559_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_025.png
# Processing image: Imagei01_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_016.png
# Processing image: Imagei550_039.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_039.png
# Processing image: Imageio564_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_020.png
# Processing image: Imagei074_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_012.png
# Processing image: Imageio558_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_026.png
# Processing image: Imageio556_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio556_030.png
# Processing image: Imagei523_074.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_074.png
# Processing image: Imageio563_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_021.png
# Processing image: Imageio564_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_021.png
# Processing image: Imagei550_040.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_040.png
# Processing image: Imageio559_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_026.png
# Processing image: Imageio556_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio556_031.png
# Processing image: Imagei01_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_017.png
# Processing image: Imagei523_075.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_075.png
# Processing image: Imagei074_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_013.png
# Processing image: Imageio562_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_024.png
# Processing image: Imagei081_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_002.png
# Processing image: Imagei528_071.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_071.png
# Processing image: Imagei080_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_004.png
# Processing image: Imagei077_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_008.png
# Processing image: Imageio561_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_025.png
# Processing image: Imagei078_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_008.png
# Processing image: Imagei072_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_015.png
# Processing image: Imageio563_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_022.png
# Processing image: Imageio560_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_026.png
# Processing image: Imagei073_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_015.png
# Processing image: Imageio558_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_027.png
# Processing image: Imagei528_072.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_072.png
# Processing image: Imagei082_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_001.png
# Processing image: Imagei523_076.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_076.png
# Processing image: Imagei072_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_016.png
# Processing image: Imageio561_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_026.png
# Processing image: Imageio556_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio556_032.png
# Processing image: Imageio564_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_022.png
# Processing image: Imageio559_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_027.png
# Processing image: Imagei081_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_003.png
# Processing image: Imageio558_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_028.png
# Processing image: Imageio563_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_023.png
# Processing image: Imagei078_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_009.png
# Processing image: Imageio562_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_025.png
# Processing image: Imagei074_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_014.png
# Processing image: Imageio560_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_027.png
# Processing image: Imagei080_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_005.png
# Processing image: Imagei073_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_016.png
# Processing image: Imagei01_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_018.png
# Processing image: Imagei083_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_001.png
# Processing image: Imagei077_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_009.png
# Processing image: Imagei550_041.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_041.png
# Processing image: Imageio559_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_028.png
# Processing image: Imagei01_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_019.png
# Processing image: Imagei078_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_010.png
# Processing image: Imageio561_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_027.png
# Processing image: Imageio558_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_029.png
# Processing image: Imageio564_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_023.png
# Processing image: Imagei523_077.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_077.png
# Processing image: Imageio560_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_028.png
# Processing image: Imageio562_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_026.png
# Processing image: Imagei080_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_006.png
# Processing image: Imagei073_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_017.png
# Processing image: Imageio563_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_024.png
# Processing image: Imagei550_042.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_042.png
# Processing image: Imagei082_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_002.png
# Processing image: Imagei074_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_015.png
# Processing image: Imagei072_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_017.png
# Processing image: Imagei077_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_010.png
# Processing image: Imagei083_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_002.png
# Processing image: Imagei081_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_004.png
# Processing image: Imageio556_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio556_033.png
# Processing image: Imagei528_073.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_073.png
# Processing image: Imagei01_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_020.png
# Processing image: Imagei074_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_016.png
# Processing image: Imagei080_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_007.png
# Processing image: Imagei528_074.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_074.png
# Processing image: Imageio562_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_027.png
# Processing image: Imageio559_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_029.png
# Processing image: Imagei083_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_003.png
# Processing image: Imagei082_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_003.png
# Processing image: Imagei081_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_005.png
# Processing image: Imagei085_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_001.png
# Processing image: Imageio564_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_024.png
# Processing image: Imagei550_043.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_043.png
# Processing image: Imagei078_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_011.png
# Processing image: Imageio561_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_028.png
# Processing image: Imagei073_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_018.png
# Processing image: Imagei072_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_018.png
# Processing image: Imagei523_078.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_078.png
# Processing image: Imagei084_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_001.png
# Processing image: Imageio563_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_025.png
# Processing image: Imagei077_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_011.png
# Processing image: Imageio558_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_030.png
# Processing image: Imageio560_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_029.png
# Processing image: Imageio562_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_028.png
# Processing image: Imageio558_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_031.png
# Processing image: Imagei086_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_001.png
# Processing image: Imageio563_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_026.png
# Processing image: Imagei084_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_002.png
# Processing image: Imagei081_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_006.png
# Processing image: Imagei080_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_008.png
# Processing image: Imagei078_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_012.png
# Processing image: Imagei528_075.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_075.png
# Processing image: Imageio560_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio560_030.png
# Processing image: Imagei01_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_021.png
# Processing image: Imagei550_044.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_044.png
# Processing image: Imageio564_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_025.png
# Processing image: Imagei074_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_017.png
# Processing image: Imagei523_079.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_079.png
# Processing image: Imagei083_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_004.png
# Processing image: Imageio561_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_029.png
# Processing image: Imagei073_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_019.png
# Processing image: Imagei072_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_019.png
# Processing image: Imagei085_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_002.png
# Processing image: Imagei082_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_004.png
# Processing image: Imagei077_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_012.png
# Processing image: Imagei080_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_009.png
# Processing image: Imageio559_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_030.png
# Processing image: Imagei078_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_013.png
# Processing image: Imagei086_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_002.png
# Processing image: Imageio562_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_029.png
# Processing image: Imagei074_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_018.png
# Processing image: Imageio561_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_030.png
# Processing image: Imagei523_080.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_080.png
# Processing image: Imagei081_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_007.png
# Processing image: Imageio564_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_026.png
# Processing image: Imagei077_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_013.png
# Processing image: Imagei550_045.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei550_045.png
# Processing image: Imagei073_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_020.png
# Processing image: Imageio563_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_027.png
# Processing image: Imagei082_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_005.png
# Processing image: Imageio558_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_032.png
# Processing image: Imagei072_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_020.png
# Processing image: Imagei528_076.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_076.png
# Processing image: Imagei085_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_003.png
# Processing image: Imagei083_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_005.png
# Processing image: Imagei084_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_003.png
# Processing image: Imagei01_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_022.png
# Processing image: Imageio563_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_028.png
# Processing image: Imagei087_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_001.png
# Processing image: Imagei523_081.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_081.png
# Processing image: Imageio559_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_031.png
# Processing image: Imagei084_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_004.png
# Processing image: Imagei074_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_019.png
# Processing image: Imagei078_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_014.png
# Processing image: Imagei077_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_014.png
# Processing image: Imagei080_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_010.png
# Processing image: Imagei073_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_021.png
# Processing image: Imagei072_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_021.png
# Processing image: Imagei086_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_003.png
# Processing image: Imagei082_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_006.png
# Processing image: Imagei528_077.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_077.png
# Processing image: Imagei01_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_023.png
# Processing image: Imagei085_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_004.png
# Processing image: Imageio558_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_033.png
# Processing image: Imageio564_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_027.png
# Processing image: Imageio562_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_030.png
# Processing image: Imagei081_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_008.png
# Processing image: Imagei083_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_006.png
# Processing image: Imagei086_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_004.png
# Processing image: Imageio564_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_028.png
# Processing image: Imagei083_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_007.png
# Processing image: Imagei092_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_001.png
# Processing image: Imagei080_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_011.png
# Processing image: Imagei01_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_024.png
# Processing image: Imagei087_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_002.png
# Processing image: Imageio561_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_032.png
# Processing image: Imagei090_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_001.png
# Processing image: Imagei084_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_005.png
# Processing image: Imageio559_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_032.png
# Processing image: Imagei523_082.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_082.png
# Processing image: Imageio563_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_029.png
# Processing image: Imagei074_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_020.png
# Processing image: Imageio562_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_031.png
# Processing image: Imagei085_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_005.png
# Processing image: Imagei077_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_015.png
# Processing image: Imagei073_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_022.png
# Processing image: Imagei082_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_007.png
# Processing image: Imagei078_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_015.png
# Processing image: Imagei072_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_022.png
# Processing image: Imagei528_078.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_078.png
# Processing image: Imageio558_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_034.png
# Processing image: Imagei081_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_009.png
# Processing image: Imagei528_079.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_079.png
# Processing image: Imagei086_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_005.png
# Processing image: Imageio561_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_033.png
# Processing image: Imagei077_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_016.png
# Processing image: Imagei093_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_001.png
# Processing image: Imagei080_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_012.png
# Processing image: Imagei01_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_025.png
# Processing image: Imagei078_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_016.png
# Processing image: Imageio563_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_030.png
# Processing image: Imagei072_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_023.png
# Processing image: Imagei087_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_003.png
# Processing image: Imagei074_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_021.png
# Processing image: Imagei082_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_008.png
# Processing image: Imagei092_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_002.png
# Processing image: Imagei073_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_023.png
# Processing image: Imagei085_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_006.png
# Processing image: Imageio562_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_032.png
# Processing image: Imagei084_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_006.png
# Processing image: Imagei081_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_010.png
# Processing image: Imageio558_035.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio558_035.png
# Processing image: Imageio564_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_029.png
# Processing image: Imagei090_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_002.png
# Processing image: Imageio559_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio559_033.png
# Processing image: Imagei083_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_008.png
# Processing image: Imagei094_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_001.png
# Processing image: Imagei085_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_007.png
# Processing image: Imagei090_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_003.png
# Processing image: Imageio561_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_034.png
# Processing image: Imagei087_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_004.png
# Processing image: Imagei072_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_024.png
# Processing image: Imagei092_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_003.png
# Processing image: Imagei082_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_009.png
# Processing image: Imageio563_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_031.png
# Processing image: Imagei01_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_026.png
# Processing image: Imagei081_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_011.png
# Processing image: Imagei083_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_009.png
# Processing image: Imagei095_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_001.png
# Processing image: Imagei078_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_017.png
# Processing image: Imagei073_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_024.png
# Processing image: Imagei086_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_006.png
# Processing image: Imagei094_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_002.png
# Processing image: Imagei093_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_002.png
# Processing image: Imagei080_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_013.png
# Processing image: Imageio564_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_030.png
# Processing image: Imagei074_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_022.png
# Processing image: Imagei528_080.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_080.png
# Processing image: Imagei084_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_007.png
# Processing image: Imagei077_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_017.png
# Processing image: Imageio562_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_033.png
# Processing image: Imagei083_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_010.png
# Processing image: Imagei095_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_002.png
# Processing image: Imageio563_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio563_032.png
# Processing image: Imagei082_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_010.png
# Processing image: Imagei086_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_007.png
# Processing image: Imagei085_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_008.png
# Processing image: Imagei077_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_018.png
# Processing image: Imagei073_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_025.png
# Processing image: Imagei080_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_014.png
# Processing image: Imageio562_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_034.png
# Processing image: Imagei081_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_012.png
# Processing image: Imagei074_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_023.png
# Processing image: Imagei01_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_027.png
# Processing image: Imagei087_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_005.png
# Processing image: Imagei078_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_018.png
# Processing image: Imagei072_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_025.png
# Processing image: Imagei093_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_003.png
# Processing image: Imagei092_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_004.png
# Processing image: Imageio561_035.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio561_035.png
# Processing image: Imagei094_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_003.png
# Processing image: Imagei090_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_004.png
# Processing image: Imagei528_081.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_081.png
# Processing image: Imagei084_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_008.png
# Processing image: Imageio564_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_031.png
# Processing image: Imagei528_082.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_082.png
# Processing image: Imagei086_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_008.png
# Processing image: Imagei072_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_026.png
# Processing image: Imagei081_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_013.png
# Processing image: Imagei095_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_003.png
# Processing image: Imagei074_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_024.png
# Processing image: Imagei090_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_005.png
# Processing image: Imagei094_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_004.png
# Processing image: Imagei083_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_011.png
# Processing image: Imagei077_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_019.png
# Processing image: Imageio562_035.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_035.png
# Processing image: Imagei093_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_004.png
# Processing image: Imagei078_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_019.png
# Processing image: Imagei085_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_009.png
# Processing image: Imagei080_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_015.png
# Processing image: Imagei073_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_026.png
# Processing image: Imageio564_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_032.png
# Processing image: Imagei082_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_011.png
# Processing image: Imagei01_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei01_028.png
# Processing image: Imagei087_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_006.png
# Processing image: Imagei084_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_009.png
# Processing image: Imagei092_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_005.png
# Processing image: Imagei096_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_001.png
# Processing image: Imagei073_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_027.png
# Processing image: Imagei080_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_016.png
# Processing image: Imagei083_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_012.png
# Processing image: Imagei078_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_020.png
# Processing image: Imagei094_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_005.png
# Processing image: Imagei087_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_007.png
# Processing image: Imagei074_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_025.png
# Processing image: Imagei086_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_009.png
# Processing image: Imageio564_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio564_033.png
# Processing image: Imagei082_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_012.png
# Processing image: Imagei090_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_006.png
# Processing image: Imagei081_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_014.png
# Processing image: Imagei095_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_004.png
# Processing image: Imagei077_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_020.png
# Processing image: Imagei084_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_010.png
# Processing image: Imagei093_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_005.png
# Processing image: Imageio562_036.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imageio562_036.png
# Processing image: Imagei092_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_006.png
# Processing image: Imagei085_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_010.png
# Processing image: Imagei072_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_027.png
# Processing image: Imagei085_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_011.png
# Processing image: Imagei082_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_013.png
# Processing image: Imagei087_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_008.png
# Processing image: Imagei077_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_021.png
# Processing image: Imagei097_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei097_001.png
# Processing image: Imagei083_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_013.png
# Processing image: Imagei096_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_002.png
# Processing image: Imagei074_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_026.png
# Processing image: Imagei093_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_006.png
# Processing image: Imagei080_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_017.png
# Processing image: Imagei081_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_015.png
# Processing image: Imagei095_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_005.png
# Processing image: Imagei086_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_010.png
# Processing image: Imagei084_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_011.png
# Processing image: Imagei072_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_028.png
# Processing image: Imagei092_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_007.png
# Processing image: Imagei094_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_006.png
# Processing image: Imagei078_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_021.png
# Processing image: Imagei090_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_007.png
# Processing image: Imagei073_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_028.png
# Processing image: Imagei078_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_022.png
# Processing image: Imagei073_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_029.png
# Processing image: Imagei074_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_027.png
# Processing image: Imagei077_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_022.png
# Processing image: Imagei528_083.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_083.png
# Processing image: Imagei072_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_029.png
# Processing image: Imagei081_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_016.png
# Processing image: Imagei093_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_007.png
# Processing image: Imagei085_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_012.png
# Processing image: Imagei094_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_007.png
# Processing image: Imagei095_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_006.png
# Processing image: Imagei080_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_018.png
# Processing image: Imagei087_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_009.png
# Processing image: Imagei096_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_003.png
# Processing image: Imagei082_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_014.png
# Processing image: Imagei098_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei098_001.png
# Processing image: Imagei090_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_008.png
# Processing image: Imagei084_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_012.png
# Processing image: Imagei092_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_008.png
# Processing image: Imagei097_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei097_002.png
# Processing image: Imagei083_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_014.png
# Processing image: Imagei086_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_011.png
# Processing image: Imagei087_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_010.png
# Processing image: Imagei084_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei084_013.png
# Processing image: Imagei077_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei077_023.png
# Processing image: Imagei095_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei095_007.png
# Processing image: Imagei098_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei098_002.png
# Processing image: Imagei074_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei074_028.png
# Processing image: Imagei094_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_008.png
# Processing image: Imagei093_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei093_008.png
# Processing image: Imagei081_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei081_017.png
# Processing image: Imagei097_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei097_003.png
# Processing image: Imagei078_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei078_023.png
# Processing image: Imagei096_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_004.png
# Processing image: Imagei086_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_012.png
# Processing image: Imagei085_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei085_013.png
# Processing image: Imagei092_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei092_009.png
# Processing image: Imagei073_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei073_030.png
# Processing image: Imagei528_084.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_084.png
# Processing image: Imagei083_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei083_015.png
# Processing image: Imagei090_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei090_009.png
# Processing image: Imagei080_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei080_019.png
# Processing image: Imagei082_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_015.png
# Processing image: Imagei072_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_030.png
# Processing image: Imagei082_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei082_016.png
# Processing image: Imagei072_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei072_031.png
# Processing image: Imagei094_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei094_009.png
# Processing image: Imagei087_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei087_011.png
# Processing image: Imagei098_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei098_003.png
# Processing image: Imagei086_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei086_013.png
# Processing image: Imagei528_085.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_085.png
# Processing image: Imagei093_009.png
# ...
# Processing image: Imagei096_047.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_047.png
# Processing image: Imagei079_064.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei079_064.png
# Processing image: Imagei096_048.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_048.png
# Processing image: Imagei096_049.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_049.png
# Processing image: Imagei096_050.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_050.png
# Processing image: Imagei096_051.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_051.png
# Processing image: Imagei096_052.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_052.png
# Processing image: Imagei096_053.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_053.png
# Processing image: Imagei096_054.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_054.png
# Processing image: Imagei096_055.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_055.png
# Processing image: Imagei096_056.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_056.png
# Processing image: Imagei096_057.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_057.png
# Processing image: Imagei096_058.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_058.png
# Processing image: Imagei096_059.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_059.png
# Processing image: Imagei096_060.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei096_060.png
# Processing image: Image000166_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_027.png
# Processing image: Image000166_038.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_038.png
# Processing image: Image000166_037.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_037.png
# Processing image: Image000166_048.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_048.png
# Processing image: Image000166_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_018.png
# Processing image: Image000166_028.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_028.png
# Processing image: Image000166_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_017.png
# Processing image: Image000166_051.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_051.png
# Processing image: Image000166_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_031.png
# Processing image: Image000166_060.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_060.png
# Processing image: Image000166_061.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_061.png
# Processing image: Image000166_009.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_009.png
# Processing image: Image000166_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_032.png
# Processing image: Image000166_016.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_016.png
# Processing image: Image000166_036.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_036.png
# Processing image: Image000166_012.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_012.png
# Processing image: Image000166_052.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_052.png
# Processing image: Image000166_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_006.png
# Processing image: Image000166_015.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_015.png
# Processing image: Image000166_046.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_046.png
# Processing image: Image000166_050.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_050.png
# Processing image: Image000166_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_034.png
# Processing image: Image000166_014.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_014.png
# Processing image: Image000166_040.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_040.png
# Processing image: Image000166_059.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_059.png
# Processing image: Image000166_042.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_042.png
# Processing image: Image000166_044.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_044.png
# Processing image: Image000166_058.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_058.png
# Processing image: Image000166_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_004.png
# Processing image: Image000166_035.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_035.png
# Processing image: Image000166_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_003.png
# Processing image: Image000166_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_029.png
# Processing image: Image000166_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_005.png
# Processing image: Image000166_047.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_047.png
# Processing image: Image000166_045.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_045.png
# Processing image: Image000166_057.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_057.png
# Processing image: Image000166_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_026.png
# Processing image: Image000166_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_033.png
# Processing image: Image000166_041.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_041.png
# Processing image: Image000166_054.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_054.png
# Processing image: Image000166_053.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_053.png
# Processing image: Image000166_011.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_011.png
# Processing image: Image000166_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_020.png
# Processing image: Image000166_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_010.png
# Processing image: Image000166_007.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_007.png
# Processing image: Image000166_055.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_055.png
# Processing image: Image000166_056.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_056.png
# Processing image: Image000166_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_030.png
# Processing image: Image000166_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_024.png
# Processing image: Image000166_008.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_008.png
# Processing image: Image000166_039.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_039.png
# Processing image: Image000166_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_023.png
# Processing image: Image000166_001.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_001.png
# Processing image: Image000166_049.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_049.png
# Processing image: Image000166_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_019.png
# Processing image: Image000166_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_022.png
# Processing image: Image000166_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_021.png
# Processing image: Image000166_025.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_025.png
# Processing image: Image000166_043.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_043.png
# Processing image: Image000166_002.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_002.png
# Processing image: Image000166_013.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image000166_013.png
# Processing image: .DS_Store
# Processing image: Imagei520_037.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei520_037.png
# Processing image: Image2480_070.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image2480_070.png
# Processing image: Imagei525_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei525_032.png
# Processing image: Imagei539_019.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei539_019.png
# Processing image: Imagei528_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_032.png
# Processing image: Imagei523_035.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_035.png
# Processing image: Imagei535_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei535_023.png
# Processing image: Imagei512_041.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei512_041.png
# Processing image: Imagei515_038.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei515_038.png
# Processing image: Imagei537_021.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei537_021.png
# Processing image: Imagei545_005.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei545_005.png
# Processing image: Imagei526_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei526_033.png
# Processing image: Imagei506_044.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei506_044.png
# Processing image: Imagei531_029.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei531_029.png
# Processing image: Imagei533_026.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei533_026.png
# Processing image: Imagei519_037.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei519_037.png
# Processing image: Imagei548_003.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei548_003.png
# Processing image: Imagei537_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei537_022.png
# Processing image: Imagei528_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei528_033.png
# Processing image: Imagei542_017.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei542_017.png
# Processing image: Image2490_065.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image2490_065.png
# Processing image: Imagei522_037.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei522_037.png
# Processing image: Imagei546_004.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei546_004.png
# Processing image: Imagei519_038.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei519_038.png
# Processing image: Imagei534_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei534_024.png
# Processing image: Imagei533_027.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei533_027.png
# Processing image: Imagei541_018.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei541_018.png
# Processing image: Imagei513_042.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei513_042.png
# Processing image: Imagei530_031.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei530_031.png
# Processing image: Imagei543_010.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei543_010.png
# Processing image: Imagei536_023.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei536_023.png
# Processing image: Imagei515_039.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei515_039.png
# Processing image: Image2480_071.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Image2480_071.png
# Processing image: Imagei539_020.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei539_020.png
# Processing image: Imagei538_022.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei538_022.png
# Processing image: Imagei535_024.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei535_024.png
# Processing image: Imagei523_036.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei523_036.png
# Processing image: Imagei517_039.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei517_039.png
# Processing image: Imagei512_042.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei512_042.png
# Processing image: Imagei526_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei526_034.png
# Processing image: Imagei545_006.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei545_006.png
# Processing image: Imagei529_032.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei529_032.png
# Processing image: Imagei524_034.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei524_034.png
# Processing image: Imagei518_039.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei518_039.png
# Processing image: Imagei531_030.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei531_030.png
# Processing image: Imagei525_033.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei525_033.png
# Processing image: Imagei506_045.png
# Saved super-resolved image to /content/drive/MyDrive/SRCNN/SRGAN/non_inv/Imagei506_045.png
# Processing image: Imagei550_001.png
